# %% [markdown]
# # Chapter 3 exercises

# %% [markdown]
# ## Before you start
#
# Fill in your name in the code cell below.
#
# When you're done with the exercises, rename this file — right-click it in the JupyterLite file browser and choose **Rename** — to `answers03-<your first name>.ipynb` (for example, `answers03-jordan.ipynb`). Then use **File > Download** to save it to your computer, and upload that file to the Chapter 3 Exercises assignment in Schoology.

# %%
name = "YOUR NAME HERE"

import datetime
print("Name:", name)
print("Last run:", datetime.datetime.now())
# Run this cell again right before you download, so the time above is close to when you finished.

# %% [markdown]
# ## Your turn
#
# You're doing these exercises entirely on your own -- there's no in-class walkthrough for this chapter. Take your time, and if you get stuck, write down where in a comment so it's visible when you turn this in.
#
# The five exercises below are your homework, about 33 minutes total. Do them in order.
#
# <!-- teacher: ~7 min -->
# ### Exercise 1: scope check
#
# Write a function called `set_mood` that takes a parameter `mood`, creates a local variable named `feeling` equal to `mood`, and prints `feeling`.
#
# Call `set_mood('excited')`. Then, in a new line below the call, try to `print(feeling)`.
#
# In a comment, explain what error you get and why -- what does the chapter's `cat` example (in the "Variables and parameters are local" section) have to do with what just happened here?

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~6 min -->
# ### Exercise 2: read the traceback
#
# Run the cell below. It raises a `NameError`.
#
# 1. In a comment, name all three functions in the call chain, in the order the traceback lists them.
# 2. In a comment, say which one of the three was actually running when the error happened -- the other two just called it.
# 3. Fix the bug (it's a typo) so the cell runs correctly.

# %%
def announce(message):
    print(anouncement)

def daily_update(topic):
    announce(topic)

def morning_routine():
    daily_update('Good morning!')

morning_routine()

# %% [markdown]
# <!-- teacher: ~8 min -->
# ### Exercise 3: functions calling functions
#
# Write a function called `shout` that takes a parameter `word` and prints the word followed by `'!!!'`, using string concatenation from chapter 1.
#
# Then write a function called `greet` that takes a parameter `name` and calls `shout` to print a greeting that includes the name, the same way `print_verse` in the chapter called `first_two_lines` and `last_three_lines` instead of doing everything itself.

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~8 min -->
# ### Exercise 4: math + functions review
#
# Remember the Pythagorean theorem exercise from chapter 2? Write a function called `show_hypotenuse` that takes two parameters, `a` and `b`, computes the hypotenuse using `math.sqrt` and `**` the same way you did there (remember to `import math` first), and prints a sentence with the result -- something like `The hypotenuse is 15.0`.
#
# Call it with a few different pairs of leg lengths to check that it works, including `9` and `12`.

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~4 min -->
# ### Exercise 5: reflection
#
# Which do you think is more useful to you right now: functions calling other functions, or the `for` loop? Why?
#
# Answer in the markdown cell below, the same way you did in chap01 and chap02.

# %% [markdown]
# *Type your answer here.*

# %% [markdown]
# ---
#
# When you're finished, rename this file (`answers03-<your first name>.ipynb`), download it, and upload it to the Chapter 3 Exercises assignment in Schoology.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/porttack/working-in-python/raw/v3/working_in_python.py');

import working_in_python
working_in_python.show_copy_notebook_button()
