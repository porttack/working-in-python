# %% [markdown]
# *GENERATED FROM chap01-exercises.ipynb - DO NOT EDIT. Source of truth is chapters/.*

# %% [markdown]
# # Chapter 1 exercises

# %% [markdown]
# ## Before you start
#
# Fill in your name in the code cell below.
#
# When you're done with the exercises, rename this file — right-click it in the JupyterLite file browser and choose **Rename** — to `answers01-<your first name>.ipynb` (for example, `answers01-jordan.ipynb`). Then use **File > Download** to save it to your computer, and upload that file to the Chapter 1 Exercises assignment in Schoology.

# %%
name = "YOUR NAME HERE"

import datetime
print("Name:", name)
print("Last run:", datetime.datetime.now())
# Run this cell again right before you download, so the time above is close to when you finished.

# %% [markdown]
# ## Your turn
#
# The five exercises below are your homework, about 30 minutes total. Do them in order.
#
# <!-- teacher: ~6 min -->
# ### Exercise 1: order of operations
#
# The formula for converting Celsius to Fahrenheit is `F = C * 9/5 + 32`.
#
# 1. Write an expression that converts 20°C to Fahrenheit. Predict the answer before you run the cell.
# 2. Now write `C * 9 / (5 + 32)` using the same value of `C`. In a comment, explain in one sentence why this gives a different — and wrong — answer.

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~5 min -->
# ### Exercise 2: splitting cookies
#
# You have 23 cookies to split evenly among 5 students.
#
# 1. Write an expression using `//` for how many whole cookies each student gets.
# 2. Without using the `%` operator (we haven't covered it yet), write an expression using only `-`, `*`, and `//` for how many cookies are left over.

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~8 min -->
# ### Exercise 3: name banner
#
# Using `+` and `*`, build a one-line banner that includes your name, decorated with a border made of a repeated character (for example, dashes or asterisks).
#
# Then use `len` on your name and answer in a comment: is the number `len` gives you what you expected? Why or why not?

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~6 min -->
# ### Exercise 4: fix the TypeError
#
# The cell below raises a `TypeError`.
#
# 1. In a comment, explain what the error message means, using the names of the two operand types it mentions.
# 2. Fix the code so it runs, using `str`.
# 3. In the cell after it, fix the same problem a different way, using `int` on a numeric string instead.

# %%
'Score: ' + 95

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~4 min -->
# ### Exercise 5: reflection
#
# Describe a time you debugged something that wasn't code -- a recipe, a Wi-Fi problem, directions that didn't work. What was the "bug," and how did you find it?
#
# Answer in the markdown cell below, the same way you did with the difference-between-`/`-and-`//` question in chap01.

# %% [markdown]
# *Type your answer here.*

# %% [markdown]
# ---
#
# When you're finished, rename this file (`answers01-<your first name>.ipynb`), download it, and upload it to the Chapter 1 Exercises assignment in Schoology.
