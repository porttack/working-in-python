# %% [markdown]
# *GENERATED FROM chap02-exercises.ipynb - DO NOT EDIT. Source of truth is chapters/.*

# %% [markdown]
# # Chapter 2 exercises

# %% [markdown]
# ## Before you start
#
# Fill in your name in the code cell below.
#
# When you're done with the exercises, rename this file — right-click it in the JupyterLite file browser and choose **Rename** — to `answers02-<your first name>.ipynb` (for example, `answers02-jordan.ipynb`). Then use **File > Download** to save it to your computer, and upload that file to the Chapter 2 Exercises assignment in Schoology.

# %%
name = "YOUR NAME HERE"

import datetime
print("Name:", name)
print("Last run:", datetime.datetime.now())
# Run this cell again right before you download, so the time above is close to when you finished.

# %% [markdown]
# ## Your turn
#
# You're doing these exercises entirely on your own -- there's no in-class walkthrough for this chapter. Take your time, and if you get stuck, write down where in a comment so it's visible when you turn this in.
#
# The five exercises below are your homework, about 35 minutes total. Do them in order.
#
# <!-- teacher: ~8 min -->
# ### Exercise 1: trace the values
#
# Below is a short sequence of assignment statements. Before you run the cell, write down (in a comment above each line) what you think the value of each variable is *after* that line runs.
#
# ```python
# a = 5
# b = a + 2
# a = a + 1
# b = a * 2
# ```
#
# Then run the cell and check your predictions. If any were wrong, add a comment explaining what you missed.

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~12 min -->
# ### Exercise 2: Python as a calculator, math-class edition
#
# **Part a.** A right triangle has legs of length 9 and 12. The Pythagorean theorem says the hypotenuse `c` satisfies `c**2 = a**2 + b**2`. Create variables `a` and `b` with these values, then compute `c` using `math.sqrt` and `**`. Display the result.

# %%
# Solution goes here

# %% [markdown]
# **Part b.** An isosceles triangle has two equal sides of length 10 and a base of length 12. The height from the top down to the base splits the triangle into two right triangles, each with a base of 6 -- so it's the same theorem again, with different numbers. Compute the height and store it in a variable named `height`. Display the result.

# %%
# Solution goes here

# %% [markdown]
# **Part c.** A ramp is 20 feet long and makes a 30-degree angle with the ground. The height it rises is `length * sin(angle)`.
#
# One catch: `math.sin` expects the angle in radians, not degrees, so convert first with `math.radians`. Compute the height the ramp rises, then compute how far it extends horizontally along the ground using `math.cos` the same way.
#
# Note: the height won't come out to a perfectly clean `10.0` -- you'll get something like `9.999999999999998`. That's the same floating-point-imprecision effect from the chapter's own trig-identity exercise, not a mistake in your code.

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~6 min -->
# ### Exercise 3: arguments and TypeError
#
# 1. Predict what `round(3.14159, 2)` displays, then run it.
# 2. Now run `round(3.14159, 2, 5)`. In a comment, explain what kind of `TypeError` this is -- too many arguments, too few, or the wrong type?
# 3. Now run `round()` with no arguments at all. In a comment, explain what kind of `TypeError` this one is, and how it's different from part 2.

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~5 min -->
# ### Exercise 4: bad comment, good comment
#
# Here's a line of code:
#
# ```python
# temp = 98.6
# ```
#
# Write two versions of this line below, each with a different comment: one that's redundant with the code (like the chapter's `v = 8  # assign 8 to v` example), and one that adds real information the code doesn't already show.

# %%
# Solution goes here

# %% [markdown]
# <!-- teacher: ~4 min -->
# ### Exercise 5: reflection
#
# Of the three error types from this chapter -- syntax, runtime, and semantic -- which do you think would be hardest to notice you'd made? Why?
#
# Answer in the markdown cell below, the same way you did with the markdown-answer question in chap01.

# %% [markdown]
# *Type your answer here.*

# %% [markdown]
# ---
#
# When you're finished, rename this file (`answers02-<your first name>.ipynb`), download it, and upload it to the Chapter 2 Exercises assignment in Schoology.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/porttack/working-in-python/raw/v3/working_in_python.py');

import working_in_python
working_in_python.show_copy_notebook_button()
